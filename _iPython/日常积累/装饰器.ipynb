# %% [markdown]
# ## 实现一个简单装饰器
#
# - 装饰器原理
# - 涉及知识理解
# - 实现一个简单装饰器
#
# ### 参考链接：https://www.cnblogs.com/taichicho/p/8863529.html

# %% [markdown]
# ### 1.1 装饰器基本理论
#
# **装饰器两大原则：**
#
# 1）不修改被修饰函数的源代码
#
# 2）不修改被修饰函数的调用（运行）方式
#
# **开放封闭原则：** 程序一旦上线，就不应该修改，一旦修改就核能产生不可预估的后果。
#
# **场景：** 给线上现在运行的程序，添加新的功能，比如计算一个函数的运行时间，例如：
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2 高阶函数
# **1）高阶函数接收的参数是一个函数名**
#
# **2）高阶函数的返回值是一个函数名**
#
# **满足上面任意一个条件就可，称为高阶函数**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.3 函数嵌套
#
# 函数里面又定义一个或多个函数。
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.4 关于闭包（可实现装饰器传参）
# **闭包：在一个作用域里放入定义变量，相当于打了一个包**
#
# **闭和包的概念**
#
# 闭：封装变量的意思，最里层 就是name变量
#
# 包： 如下图，一个圈代表一个包，代表一层，
#
# 如图：
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.5 装饰器的基本实现
# **装饰器=高阶函数+闭包+函数嵌套**
#
# 那么就先写一个框架：
# ![image.png](attachment:image.png)
