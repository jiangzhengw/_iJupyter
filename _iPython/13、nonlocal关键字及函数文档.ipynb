# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# nonlocal在内函数中 使用上层函数定义的不可变数据类型的变量

def outer():
    num=10
    def inner():
        nonlocal num
        return num+1
    return inner()

outer()
# Out:
# [1, 2, 3, 4]

# %%
"""
说明文档
"""

def a():
    """
    a函数的文档说明
    参数a：xxx
    参数b：xxx
    return：xxx
    """
    pass
# print(globals())
print(__name__)
print(__doc__)
print(__package__)
print(__loader__)
print(dir())

print(a.__doc__)
# Out:
# __main__
#
# 说明文档
#
# None
# None
# ['In', 'Out', '_', '_2', '_3', '_5', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'a', 'exit', 'get_ipython', 'outer', 'quit']
#
#     a函数的文档说明
#     参数a：xxx
#     参数b：xxx
#     return：xxx
